# %% [markdown]
# <a href="https://colab.research.google.com/github/NickLin910221/nutn_DBscience_course/blob/master/textmining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("rJava")
install.packages("jiebaR")
install.packages("tmcn")
install.packages("dplyr")
install.packages("lubridate")
install.packages("stringr")
install.packages("wordcloud")
install.packages("Rwordseg",repos = "http://R-Forge.R-project.org")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “dependency ‘HMM’ is not available”
# Warning message in install.packages("Rwordseg", repos = "http://R-Forge.R-project.org"):
# “installation of package ‘Rwordseg’ had non-zero exit status”

# %%
library(dplyr)
library(lubridate)
library(stringr)
library(jiebaR)
library(wordcloud)

# %%
install.packages("showtext")
library(showtext)
showtext.auto(enable = TRUE)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
content <- "嚴重特殊傳染性肺炎疫情持續在全球蔓延,已造成三千多萬人感染,死亡人數破百萬人,歐美醫療體系幾近崩潰,各種行動限制對於各國之經濟更有莫大之衝擊。然而台灣未實行大規模封鎖行動,維持正常上班上課與各種經濟活動,至今無大規模疫情爆發,醫療體系也仍能正常提供民眾服務,顯示台灣的防疫政策正確而有效,
獲得世界各國高度肯定。國家衛生研究院群體健康科學研究所與感染症與疫苗研究所合作,利用真實數據與數學模型證實,良好的邊境管控,詳盡的疫情調查,確實的隔離與檢疫,以及民眾遵行防疫措施,為台灣抗疫四大支柱。台灣也對世界各國提供各項協助與經驗分享,期望幫助各國盡快從疫情的陰霾中走出。"

# %%
cutter <- worker(bylines = F)

# %%
cutter[content]
# Out:
#   [1] "嚴重"           "特殊"           "傳染性"         "肺炎"
#   [5] "疫情"           "持續"           "在"             "全球"
#   [9] "蔓延"           "已"             "造成"           "三千多萬"
#  [13] "人"             "感染"           "死亡"           "人數"
#  [17] "破"             "百萬"           "人"             "歐美"
#  [21] "醫療"           "體系"           "幾近"           "崩潰"
#  [25] "各種"           "行動"           "限制"           "對於"
#  [29] "各國"           "之"             "經濟"           "更"
#  [33] "有"             "莫大"           "之"             "衝擊"
#  [37] "然而"           "台灣"           "未"             "實行"
#  [41] "大規模"         "封鎖"           "行動"           "維持"
#  [45] "正常"           "上班"           "上課"           "與"
#  [49] "各種"           "經濟"           "活動"           "至今"
#  [53] "無"             "大規模"         "疫情"           "爆發"
#  [57] "醫療"           "體系"           "也"             "仍"
#  [61] "能"             "正常"           "提供"           "民眾"
#  [65] "服務"           "顯示"           "台灣"           "的"
# ...

# %%
new_words = c("傳染性肺炎","醫療體系","防疫措施")
stop_words = c("在","之","更","個","未","而","也","與","的","但","點或","點")
for (i in 1:length(new_words)) {
  new_user_word(cutter,new_words[i])
}
content = str_remove_all(content,"[0-9a-zA-Z]+?")
cutter[content]
# Out:
#   [1] "嚴重"           "特殊"           "傳染性肺炎"     "疫情"
#   [5] "持續"           "在"             "全球"           "蔓延"
#   [9] "已"             "造成"           "三千多萬"       "人"
#  [13] "感染"           "死亡"           "人數"           "破"
#  [17] "百萬"           "人"             "歐美"           "醫療體系"
#  [21] "幾近"           "崩潰"           "各種"           "行動"
#  [25] "限制"           "對於"           "各國"           "之"
#  [29] "經濟"           "更"             "有"             "莫大"
#  [33] "之"             "衝擊"           "然而"           "台灣"
#  [37] "未"             "實行"           "大規模"         "封鎖"
#  [41] "行動"           "維持"           "正常"           "上班"
#  [45] "上課"           "與"             "各種"           "經濟"
#  [49] "活動"           "至今"           "無"             "大規模"
#  [53] "疫情"           "爆發"           "醫療體系"       "也"
#  [57] "仍"             "能"             "正常"           "提供"
#  [61] "民眾"           "服務"           "顯示"           "台灣"
#  [65] "的"             "防疫"           "政策"           "正確"
# ...

# %%
writeLines(new_words,"new_words.txt")
writeLines(stop_words,"stop_words.txt")
cutter = worker(user = "new_words.txt",stop_word = "stop_words.txt",bylines = FALSE)
seg_words = cutter[content]
seg_words
# Out:
#   [1] "嚴重"           "特殊"           "傳染性肺炎"     "疫情"
#   [5] "持續"           "全球"           "蔓延"           "已"
#   [9] "造成"           "三千多萬"       "人"             "感染"
#  [13] "死亡"           "人數"           "破"             "百萬"
#  [17] "人"             "歐美"           "醫療體系"       "幾近"
#  [21] "崩潰"           "各種"           "行動"           "限制"
#  [25] "對於"           "各國"           "經濟"           "有"
#  [29] "莫大"           "衝擊"           "然而"           "台灣"
#  [33] "實行"           "大規模"         "封鎖"           "行動"
#  [37] "維持"           "正常"           "上班"           "上課"
#  [41] "各種"           "經濟"           "活動"           "至今"
#  [45] "無"             "大規模"         "疫情"           "爆發"
#  [49] "醫療體系"       "仍"             "能"             "正常"
#  [53] "提供"           "民眾"           "服務"           "顯示"
#  [57] "台灣"           "防疫"           "政策"           "正確"
#  [61] "有效"           "獲得"           "世界"           "各國"
#  [65] "高度肯定"       "國家衛生研究院" "群體"           "健康"
# ...

# %%
# 計算詞彙頻率
txt_freq = freq(seg_words)
# 由大到小排列
txt_freq = arrange(txt_freq,desc(freq))
head(txt_freq)
# Out:
#   char freq
# 1 各國 4
# 2 疫情 4
# 3 台灣 4
# 4 行動 2
# 5 各種 2
# 6 經濟 2

# %%
wordcloud(txt_freq$char,txt_freq$freq,min.freq = 5,random.color = F,ordered.colors = F,colors = rainbow(nrow(txt_freq)))
# Out:
# plot without title
